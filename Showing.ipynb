# %%
from ctu_crs import CRS97
import solution
import puzzle

# %%
robot = CRS97()
# Out:
# Firmware version : MARS8 v1.0 build Pi Oct  2 2017 11:06:45

# %%
robot.initialize(home=True)
# Out:
# Firmware version : MARS8 v1.0 build Pi Oct  2 2017 11:06:45

# %%
robot.initialize(home=False)

# %%
robot.soft_home()

# %%
robot.release()

# %%
T_RC_def = [[-4.91410691e-03, 9.98341087e-01, -5.73665839e-02, 4.90644721e+02],
                [9.97906036e-01, 1.19594619e-03, -6.46692634e-02, 2.38816422e+01],
                [-6.44933754e-02, -5.75642520e-02, -9.96256474e-01, 1.19549166e+03],
                [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00]]
T_RC_12rand = [[-3.09275095e-02 , 9.98889991e-01, -3.55285092e-02,  4.71849312e+02],
 [ 9.99249525e-01,  3.00701923e-02, -2.44165920e-02, -1.25522968e+01],
 [-2.33211402e-02 ,-3.62569903e-02 ,-9.99070345e-01 , 1.19959167e+03],
 [ 0.00000000e+00 , 0.00000000e+00 , 0.00000000e+00 , 1.00000000e+00]]

# %%
maze = puzzle.PuzzleA()
solution.solve_maze(maze, robot, T_RC_12rand)

# %%
maze = puzzle.PuzzleB()
solution.solve_maze(maze, robot, T_RC_12rand)
# Out:
# [[1]
#  [2]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 maze = puzzle.PuzzleB()
# ----> 2 solution.solve_maze(maze, robot, T_RC_12rand)
#
# File ~/PycharmProjects/ROBSemestralka/solution.py:66, in solve_maze(puzzle, robot, T_RC, normal_vector)
#      64 start = maze_f_robot_coord[0].copy()
#      65 start[2] += 0.05
# ---> 66 arm_vector = arm_vector_decider(maze_f_robot_coord, normal_vector, robot)
#      67 if arm_vector is None:
#      68     raise Exception('No valid arm vector found')
#
# File ~/PycharmProjects/ROBSemestralka/solution.py:47, in arm_vector_decider(maze_f_robot_coord, normal, robot)
#      45 q0 = robot.q_home
#      46 for point in maze_f_robot_coord:
# ---> 47     pose = PoseComposer.make_se3_matrix(vector, point, normal)
#      48     robot_config = robot_configuration_maker(pose, robot, q0)
#      49     q0 = robot_config
#
# File ~/PycharmProjects/ROBSemestralka/PoseComposer.py:26, in make_se3_matrix(circle_pos, circle_arm_vector, circle_normal_vector, tolerance, circle_arm_length)
#      14 """
#      15 IK of the hoop
#      16 :param circle_pos:
#    (...)     21 :return:
#      22 """
#      23 # TODO: write docstring
#      24
#      25 # check that the normal and arm vectors are perpendicular
# ---> 26 assert (np.isclose(np.dot(circle_arm_vector, circle_normal_vector), 0.0, atol=tolerance))
#      27 # directional vectors cannot be 0
#      28 assert (np.linalg.norm(circle_arm_vector) != 0 and np.linalg.norm(circle_normal_vector) != 0)
#
# AssertionError:

# %%
maze = puzzle.PuzzleC()
solution.solve_maze(maze, robot, T_RC_12rand)
